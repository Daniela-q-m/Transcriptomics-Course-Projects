# %% [markdown]
# The purpose of this analysis is to analyze publicly available Affymetrix microarray data. The goal is to perform a differential gene expression analysis.

# %%
install.packages("BiocManager")
BiocManager::install("GOstats")
≈
BiocManager::install("GO.db")
BiocManager::install("Category")
BiocManager::install("ath1121501.db")
BiocManager::install("AnnotationDbi")
BiocManager::install("annotate")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.r-project.org
#
#
# Bioconductor version 3.10 (BiocManager 1.30.16), R 3.6.1 (2019-07-05)
#
# Installing package(s) 'BiocVersion', 'GOstats'
#
# also installing the dependencies ‘bit’, ‘bit64’, ‘blob’, ‘DBI’, ‘Rcpp’, ‘BiocGenerics’, ‘GSEABase’, ‘genefilter’, ‘IRanges’, ‘RSQLite’, ‘S4Vectors’, ‘XML’, ‘RCurl’, ‘Biobase’, ‘Category’, ‘graph’, ‘AnnotationDbi’, ‘GO.db’, ‘RBGL’, ‘annotate’, ‘AnnotationForge’, ‘Rgraphviz’
#
#
# Warning message in .inet_warning(msg):
# “installation of package ‘bit’ had non-zero exit status”
# Warning message in .inet_warning(msg):
# “installation of package ‘Rcpp’ had non-zero exit status”
# Warning message in .inet_warning(msg):
# “installation of package ‘XML’ had non-zero exit status”
# ...

# %%
#Use getGEO command to downlaod the data
gse<-getGEO("GSE38102")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
# Error in library(GEOquery): there is no package called ‘GEOquery’
# Traceback:
#
# 1. library(GEOquery)

# %%
install.packages("GEOquery")
# Out:
# Warning message:
# “package ‘GEOquery’ is not available (for R version 3.6.1)”
