# %% [markdown]
# ## Part 1

# %% [markdown]
# Create a matrix called transcriptome

# %%
#Make vectors with column and row names
elements<-c('Control','Nitrogen','Phosphate','Potassium')
genes<-c('GeneA','GeneB','GeneC','GeneD','GeneE')

#Make vectors with the value of every column
Control<-c(89,90,78,81,62)
Nitrogen<-c(78,99,94,83,51)
Phosphate<-c(77,85,99,80,99)
Potassium<-c(56,97,87,79,88)

#Create matrix with vectors defined as columns
#Name rows and columns with previously defined string vectors, print matrix
transcriptome<-matrix(c(Control, Nitrogen, Phosphate, Potassium),nrow=5,ncol=4)
colnames(transcriptome)<-elements
rownames(transcriptome)<-genes
transcriptome
# Out:
#       Control Nitrogen Phosphate Potassium
# GeneA 89      78       77        56
# GeneB 90      99       85        97
# GeneC 78      94       99        87
# GeneD 81      83       80        79
# GeneE 62      51       99        88

# %% [markdown]
# Calculate the Average expression for each gene accross all genes

# %%
#Loop through every row in the matrix and assign the mean to expression_average vector 
expression_average=numeric()
for (i in 1:nrow(transcriptome)){
    expression_average[i]=(mean(transcriptome[i,]))  
}
print(expression_average)
# Out:
# [1] 75.00 92.75 89.50 80.75 75.00

# %%
#Added expression_average column w/ cbind
transcriptome<-cbind(transcriptome, expression_average)
transcriptome
# Out:
#       Control Nitrogen Phosphate Potassium expression_average
# GeneA 89      78       77        56        75.00
# GeneB 90      99       85        97        92.75
# GeneC 78      94       99        87        89.50
# GeneD 81      83       80        79        80.75
# GeneE 62      51       99        88        75.00

# %% [markdown]
# Sort the matrix so that the gene with the highest expression is on top.

# %%
#Gene B has the highest avg expression, sorted in decreasing order, transcriptome assigned to new dataframe, sorted_genes
sorted_genes<-transcriptome[order(-expression_average),]
sorted_genes
# Out:
#       Control Nitrogen Phosphate Potassium expression_average
# GeneB 90      99       85        97        92.75
# GeneC 78      94       99        87        89.50
# GeneD 81      83       80        79        80.75
# GeneA 89      78       77        56        75.00
# GeneE 62      51       99        88        75.00

# %% [markdown]
# Fold Change calculation

# %%
getwd()
# Out:
# [1] "/Users/danielaquijano/Documents/NYU MASTERS/SPRING 2022/Transcriptomics"

# %%
#Read in file as a table. Print first few rows
data=read.table('/Users/danielaquijano/Documents/NYU MASTERS/SPRING 2022/Transcriptomics/Source_Files/expvalues.txt',sep='')
#head(data)
data
typeof(data[1:3,1:3])
# Out:
#                         Control1     Control2    Control3    Treatment1
# 244901_at                229.985654   353.59949   178.49171   112.908004
# 244902_at                171.149796    84.45094    41.37195   170.172616
# 244903_at                314.977684   373.31250    52.90873   196.302559
# 244904_at                 24.043665   175.31604    94.68424    82.784879
# 244905_at                 15.869235    40.04125    58.76573   341.353405
# 244906_at                381.063794   218.90597   307.01488   162.541085
# 244907_at                 42.149034   101.48822    60.07721   141.729674
# 244908_at                  3.689773    19.74626    20.45402    12.121181
# 244909_at                103.840665    60.91570   100.70570   232.722276
# 244910_s_at               54.568021   208.21758   261.46866    55.664967
# 244911_at                 33.459830    24.80430   333.04504    55.434718
# 244912_at               1908.136722  1722.11193  1015.58316  1451.123436
# 244913_at                 38.116250    57.01160    50.12533    13.602490
# 244914_at                  9.206320    23.66153    37.63685    25.381654
# 244915_s_at               83.591232    13.32849    52.45875    89.643047
# 244916_at                  3.371939    38.96267    16.94395    68.912713
# 244917_at                 12.290308    16.83069    19.14878    48.150699
# 244918_at                 13.524077    10.25547   118.22959    16.269613
# 244919_at                 52.526800    79.54758   117.32549    11.163423
# 244920_s_at             1013.596105  1192.22287   745.71222  1315.596379
# 244921_s_at              367.634554   395.64442   226.89184   707.185370
# 244915_s_at                4.944875     7.282426
# 244916_at                  2.800184    52.709338
# 244917_at                 10.206957    38.330828
# 244918_at                  6.718628    50.917740
# 244919_at                 22.767374   165.390528
# 244920_s_at              604.654588   973.765823
# 244921_s_at              269.237938   544.451803
# 244922_s_at               53.908678   167.852959
# 244923_s_at               91.140857    21.753151
# 244924_at                117.887705   319.370348
# 244925_at                 41.618571    29.012832
# 244926_s_at               52.687265    11.033588
# 244927_at                150.291281    37.409891
# 244928_s_at              190.056294   334.913306
# 244929_at               1141.268476  1046.554456
# 244930_at                 99.201200    21.045633
# ...                     ...          ...
# AFFX-TrpnX-M_at             3.291846     9.195824
# AFFX-r2-At-Actin-3_s_at  6187.229784  4924.238579
# AFFX-r2-At-Actin-5_s_at  2766.804286  2177.766648
# AFFX-r2-At-Actin-M_s_at  5005.466143  4326.461829
# AFFX-r2-At-GAPDH-3_s_at  8245.887618  7394.571582
# AFFX-r2-At-GAPDH-5_s_at  9840.309957  8376.484761
# AFFX-r2-At-U12639_at       33.839154   153.299663
# AFFX-r2-At-Ubq-3_x_at   15382.463969 16074.746766
# AFFX-r2-At-Ubq-5_x_at   15618.077520 16754.749773
# AFFX-r2-Bs-dap-3_at      1446.003524   806.037935
# AFFX-r2-Bs-dap-5_at      1199.611623   452.155740
# AFFX-r2-Bs-dap-M_at      1182.532885   594.902376
# AFFX-r2-Bs-lys-3_at       182.018383    20.584782
# AFFX-r2-Bs-lys-5_at       104.291202    73.942765
# AFFX-r2-Bs-lys-M_at        84.481429   129.609770
# AFFX-r2-Bs-phe-3_at       292.548152   199.769147
# AFFX-r2-Bs-phe-5_at       148.446297    66.489310
# AFFX-r2-Bs-phe-M_at       218.994024    18.927038
# AFFX-r2-Bs-thr-3_s_at     494.423022   253.251664
# AFFX-r2-Bs-thr-5_s_at     463.278556   248.047869
# AFFX-r2-Bs-thr-M_s_at     533.399252   275.479069
# AFFX-r2-Ec-bioB-3_at      302.860575   435.485023
# AFFX-r2-Ec-bioB-5_at      291.017542   176.682632
# AFFX-r2-Ec-bioB-M_at      372.097285   462.129624
# AFFX-r2-Ec-bioC-3_at      924.179204   612.544685
# AFFX-r2-Ec-bioC-5_at      887.813707   519.866021
# AFFX-r2-Ec-bioD-3_at     3342.401303  4025.453230
# AFFX-r2-Ec-bioD-5_at     2482.907029  3171.834410
# AFFX-r2-P1-cre-3_at     14465.567056 17434.822226
# AFFX-r2-P1-cre-5_at     11719.385104 16316.773237
# [1] "list"

# %%
groups<-factor(c('control','control','control','experimental','experimental','experimental'))
tapply(as.numeric(data[1,]),groups,mean)
# Out:
#      control experimental
#     254.0256     195.5529

# %%
avg_ctrl<-numeric()

for (i in 1:nrow(data)){
    avg_ctrl[i]<-(mean(data[i,1:3]))
}
print(avg_ctrl)
# Out:
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# ...
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”
# Warning message in mean.default(data[i, 1:3]):
# “argument is not numeric or logical: returning NA”

# %%
control=numeric()
experimental=numeric()

for (i in 1:nrow(data)){
        control[i]=tapply(as.numeric(data[1,2]),groups,mean)
}
print(control)

# %%
#Calculate the ratio of average treatment/ average control for each gene

# %%
#log fold change

# %%
#How many genes have a log2 fold change > 1 OR < -1

# %%
#Save the names of the genes that have a log2 fold change > 1 into a file called “Induced_genes.txt”

# %%
#create a boxplot to show the distribution of values for each induced genes in each experiment. The x-axis should have all six experiments, and the y-axis is the expression level. Save the boxplot as a pdf file called “boxplot.pdf” 
library(ggplot2)
experiments<-c('Control1','Control2','Control3','Control4','Control5','Control6')
ggplot(data, aes(x=experiments, y=note, fill=treatment)) + geom_boxplot()
